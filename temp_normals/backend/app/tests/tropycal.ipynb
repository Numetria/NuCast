# %%
from tropycal import realtime

# Get the latest advisory for Hurricane Ida

realtime_obj = realtime.Realtime()
# Out:
# --> Starting to read in current storm data
# --> Completed reading in current storm data (0.22 seconds)

# %%
realtime_obj.plot_summary(domain={'w':-100,'e':-10,'s':4,'n':60})


# remove the trop
# Out:
# <GeoAxes: title={'left': 'Summary & NHC 7-Day Formation Outlook', 'right': 'Valid: 16 UTC 27 Feb 2025'}>
